# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('DS - Assignment Part 1 data set.xlsx')
data.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %% [markdown]
# # Exploratory data analysis using statistical methods

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Transaction date                          414 non-null    float64
#  1   House Age                                 414 non-null    float64
#  2   Distance from nearest Metro station (km)  414 non-null    float64
#  3   Number of convenience stores              414 non-null    int64
#  4   latitude                                  414 non-null    float64
#  5   longitude                                 414 non-null    float64
#  6   Number of bedrooms                        414 non-null    int64
#  7   House size (sqft)                         414 non-null    int64
#  8   House price of unit area                  414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 29.2 KB

# %%
data.describe().T
# Out:
#                                           count         mean          std  \
# Transaction date                          414.0  2013.148953     0.281995
# House Age                                 414.0    17.712560    11.392485
# Distance from nearest Metro station (km)  414.0  1083.885689  1262.109595
# Number of convenience stores              414.0     4.094203     2.945562
# latitude                                  414.0    24.969030     0.012410
# longitude                                 414.0   121.533361     0.015347
# Number of bedrooms                        414.0     1.987923     0.818875
# House size (sqft)                         414.0   931.475845   348.910269
# House price of unit area                  414.0    37.980193    13.606488
#
#                                                   min          25%  \
# Transaction date                          2012.666667  2012.916667
# House Age                                    0.000000     9.025000
# ...

# %% [markdown]
# # correlation

# %%
data.corr()
# Out:
#                                           Transaction date  House Age  \
# Transaction date                                  1.000000   0.017542
# House Age                                         0.017542   1.000000
# Distance from nearest Metro station (km)          0.060880   0.025622
# Number of convenience stores                      0.009544   0.049593
# latitude                                          0.035016   0.054420
# longitude                                        -0.041065  -0.048520
# Number of bedrooms                                0.061985  -0.008756
# House size (sqft)                                 0.068405  -0.060361
# House price of unit area                          0.087529  -0.210567
#
#                                           Distance from nearest Metro station (km)  \
# Transaction date                                                          0.060880
# House Age                                                                 0.025622
# ...

# %% [markdown]
# # pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# # heatmap

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'House price of unit area'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(data['House price of unit area'])

plt.subplot(1,2,2)
sns.kdeplot(data['House price of unit area'])
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='House price of unit area', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(data['House size (sqft)'])

plt.subplot(1,2,2)
sns.kdeplot(data['House size (sqft)'])
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='House size (sqft)', ylabel='Density'>

# %%
sns.scatterplot(data['House price of unit area'],data['Number of bedrooms'])
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='House price of unit area', ylabel='Number of bedrooms'>

# %%
data['Number of bedrooms'].value_counts()
# Out:
# 1    141
# 2    137
# 3    136
# Name: Number of bedrooms, dtype: int64

# %%
data['House Age'].value_counts()
# Out:
# 0.0     17
# 13.6     7
# 13.3     6
# 16.2     6
# 16.4     6
#         ..
# 30.2     1
# 4.3      1
# 24.0     1
# 8.4      1
# 18.8     1
# Name: House Age, Length: 236, dtype: int64

# %%
numnames=data.dtypes[data.dtypes!='object'].index

# %%
plt.figure(figsize=(15,6))
count=1
for i in numnames:
    plt.subplot(2,5,count)
    sns.boxplot(data.loc[:,i])
    count=count+1
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
plt.figure(figsize=(15,6))
count=1
for i in numnames:
    plt.subplot(2,5,count)
    sns.kdeplot(data.loc[:,i])
    count+=1

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data['Number of bedrooms'],data['House price of unit area'])
plt.title('House price of unit area vs number of bedrooms')
plt.show()
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['House price of unit area'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    27.70
# 0.50    38.45
# 0.75    46.60
# Name: House price of unit area, dtype: float64

# %% [markdown]
# # data preprocessing

# %%
x=data.iloc[:,:-1].values
x
# Out:
# array([[2.01291667e+03, 3.20000000e+01, 8.48788200e+01, ...,
#         1.21540240e+02, 1.00000000e+00, 5.75000000e+02],
#        [2.01291667e+03, 1.95000000e+01, 3.06594700e+02, ...,
#         1.21539510e+02, 2.00000000e+00, 1.24000000e+03],
#        [2.01358333e+03, 1.33000000e+01, 5.61984500e+02, ...,
#         1.21543910e+02, 3.00000000e+00, 1.06000000e+03],
#        ...,
#        [2.01325000e+03, 1.88000000e+01, 3.90969600e+02, ...,
#         1.21539860e+02, 1.00000000e+00, 5.03000000e+02],
#        [2.01300000e+03, 8.10000000e+00, 1.04810100e+02, ...,
#         1.21540670e+02, 1.00000000e+00, 5.97000000e+02],
#        [2.01350000e+03, 6.50000000e+00, 9.04560600e+01, ...,
#         1.21543100e+02, 2.00000000e+00, 1.09700000e+03]])

# %%
y=data.iloc[:,-1].values
y
# Out:
# array([ 37.9,  42.2,  47.3,  54.8,  43.1,  32.1,  40.3,  46.7,  18.8,
#         22.1,  41.4,  58.1,  39.3,  23.8,  34.3,  50.5,  70.1,  37.4,
#         42.3,  47.7,  29.3,  51.6,  24.6,  47.9,  38.8,  27. ,  56.2,
#         33.6,  47. ,  57.1,  22.1,  25. ,  34.2,  49.3,  55.1,  27.3,
#         22.9,  25.3,  47.7,  46.2,  15.9,  18.2,  34.7,  34.1,  53.9,
#         38.3,  42. ,  61.5,  13.4,  13.2,  44.2,  20.7,  27. ,  38.9,
#         51.7,  13.7,  41.9,  53.5,  22.6,  42.4,  21.3,  63.2,  27.7,
#         55. ,  25.3,  44.3,  50.7,  56.8,  36.2,  42. ,  59. ,  40.8,
#         36.3,  20. ,  54.4,  29.5,  36.8,  25.6,  29.8,  26.5,  40.3,
#         36.8,  48.1,  17.7,  43.7,  50.8,  27. ,  18.3,  48. ,  25.3,
#         45.4,  43.2,  21.8,  16.1,  41. ,  51.8,  59.5,  34.6,  51. ,
#         62.2,  38.2,  32.9,  54.4,  45.7,  30.5,  71. ,  47.1,  26.6,
#         34.1,  28.4,  51.6,  39.4,  23.1,   7.6,  53.3,  46.4,  12.2,
# ...

# %% [markdown]
# # training the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=45)

# %%
x_train.shape,y_train.shape
# Out:
# ((207, 8), (207,))

# %% [markdown]
# # Standardscaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
Regressor=LinearRegression()
Regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = Regressor.predict(x_train)
y_pred
# Out:
# array([37.21251566, 53.96869209, 18.73690388, 45.820788  , 31.76972336,
#        42.43113444, 49.662909  ,  6.3685538 , 45.56211919, 34.61160494,
#        41.27040133, 43.88790327, 32.2121988 , 10.50098445, 39.97503115,
#        27.69379984, 44.31135477, 41.42150097, 32.94440143, 45.62351664,
#        11.24446552, 44.77989116, 52.02744585, 32.6187326 , 42.78615803,
#        43.10415441, 43.9127479 , 49.05920015, 25.11604357, 31.87465525,
#        41.33932403, 43.75704403, 42.50516433, 39.19802463, 33.04636964,
#        30.99271285, 43.61692618, 48.15014974, 13.43466191, 12.04724974,
#        45.30703678, 41.75731803, 13.92886843, 11.22724782, 36.03943773,
#        35.16473933, 45.38663612, 25.75127875, 36.78150801, 15.56518666,
#        11.78373866, 42.39309527, 45.45739938, 45.29778024, 11.67149202,
#        37.76746799, 43.01294535, 45.99855958, 11.26181368, 35.6604076 ,
#        35.40240702, 45.52075034, 47.00452619, 33.04056292, 43.95858038,
# ...

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_train.reshape(len(y_train),1)),1))
# Out:
# [[ 37.21251566  30.7       ]
#  [ 53.96869209  44.7       ]
#  [ 18.73690388  22.        ]
#  [ 45.820788    56.2       ]
#  [ 31.76972336  27.3       ]
#  [ 42.43113444  44.3       ]
#  [ 49.662909    48.        ]
#  [  6.3685538   11.2       ]
#  [ 45.56211919  36.9       ]
#  [ 34.61160494  23.6       ]
#  [ 41.27040133  41.9       ]
#  [ 43.88790327  37.5       ]
#  [ 32.2121988   25.5       ]
#  [ 10.50098445  13.4       ]
#  [ 39.97503115  31.1       ]
#  [ 27.69379984  22.8       ]
#  [ 44.31135477  38.4       ]
#  [ 41.42150097  42.3       ]
#  [ 32.94440143  28.6       ]
#  [ 45.62351664  39.7       ]
#  [ 11.24446552  19.2       ]
#  [ 44.77989116  34.3       ]
#  [ 52.02744585  54.4       ]
#  [ 32.6187326   29.7       ]
#  [ 42.78615803  37.7       ]
#  [ 43.10415441  40.6       ]
#  [ 43.9127479   40.        ]
#  [ 49.05920015  51.6       ]
#  [ 25.11604357  24.8       ]
#  [ 31.87465525  25.3       ]
#  [ 41.33932403  47.        ]
#  [ 43.75704403  40.1       ]
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_train)
# Out:
# 0.2920659515469496

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr = SVR(kernel="linear")
svr.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_preds = svr.predict(x_train)
y_preds
# Out:
# array([34.63854631, 52.82478412, 22.10001139, 46.4434212 , 30.33285764,
#        41.55811882, 47.9002821 , 10.55144903, 42.32695009, 32.62794435,
#        41.99969694, 44.05099193, 28.57827007, 10.25850194, 36.94218159,
#        28.23853513, 43.05402419, 42.30105607, 31.98952339, 45.37077668,
#        13.8384989 , 41.73164206, 54.17611205, 30.13335326, 40.42490846,
#        40.61638503, 40.61387   , 47.57634473, 24.7002346 , 28.91311178,
#        39.4539144 , 40.19983304, 41.02811574, 37.68108209, 30.70859249,
#        29.70877512, 43.67527074, 45.24733431, 13.00027864, 11.52319992,
#        43.43447999, 38.20730034, 13.1860577 , 13.33116956, 33.49940393,
#        32.62836402, 42.89801464, 25.18004055, 37.06070353, 13.84634825,
#        12.71466517, 40.72663064, 44.21347993, 43.49236698, 12.4260705 ,
#        34.29315941, 43.45224072, 43.17577554, 14.41780576, 32.92251373,
#        33.35412341, 42.87641355, 43.3793167 , 30.77599698, 42.64586193,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_preds,y_train)
# Out:
# 0.20170357028475838

# %%
'''I have taken all attributes as a independent and house price prediction  as a target variable from a noise free dataset.
test_size is 0.5 and i scaled the dataset for better results and i used linear and svr algorithms to predict the results
and i used r2_score for accuracy linear regression gives the better results'''
# Out:
# 'I have taken all attributes as a independent and house price prediction  as a target variable from a noise free dataset.\ntest_size is 0.5 and i scaled the dataset for better results and i used linear and svr algorithms to predict the results\nand i used r2_score for accuracy linear regression gives the better results'

# %%
'''From linear regression and svr(support vector regression kernel = linear) 
which is used for continuous data and comparing between them linear regression given better accuracy 
because linear regression is the algorithm which have better knowledge in relation with other attributes 
But svr which separates two classes '''
# Out:
# 'From linear regression and svr(support vector regression kernel = linear) \nwhich is used for continuous data and comparing between them linear regression given better accuracy \nbecause linear regression is the algorithm which have better knowledge in relation with other attributes \nBut svr which separates two classes '
